# %%
from keras.models import Sequential

# %matplotlib inline
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Input, Conv2D, Dropout, Flatten, Dense, BatchNormalization, Reshape, UpSampling2D, Activation
from keras.optimizers import Adam, SGD
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Model
#mport time
import matplotlib.pyplot as plt
#from tqdm import tqdm
from IPython import display

# %%
width = 28
height = 28
channels = 1

# %% [markdown]
# <H2>1. Declare plots functions<H2>

# %%
def Plot_losses(losses, ymin, ymax):
    """Plotting G_loss and D_loss on train_set during training process"""

    plt.figure(figsize=(12,6))
    plt.title('Training losses ', fontsize=16)

    x  = losses[:,0]
    y1 = losses[:,1]
    y2 = losses[:,2]

    plt.xlim([0.0, max(x) + 1.0])
    plt.ylim([ymin,ymax])
    plt.xlim([-0.01*max(x), 1.01*max(x)])

    plt.plot(x, y1,  'b', label = 'D_loss')
    plt.plot(x, y2,  'g', label = 'G_loss')
    
    plt.legend(loc='upper right', fontsize=14)
    plt.ylabel('Losses', fontsize=14)
    plt.xlabel('Epochs', fontsize=14)
    #plt.savefig(path + data_name +"_traing_errors.pdf")
    plt.show()

# %%
''' Plot 16 images together. These images are either real images or fake ones'''
def plot_images(save2file=False, samples=16, step=0, images=[]):
    
    print("    ____________________ Step = %d ____________________" %step)
    plt.figure(figsize=(6, 6))
    for i in range(images.shape[0]):
        plt.subplot(4, 4, i+1)
        image = images[i, :, :, :]
        image = np.reshape(image, [height, width])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.tight_layout()

    if save2file:
        plt.savefig(str(step) + "_d.png")
        plt.close('all')
    else:
        plt.show()

# %% [markdown]
# <H2>2. Load MNIST data</H2>
#
# We use only training set without label. This is because we aim to train generator to produce images that are very similar to real images. The pixel values in MNIST ranging from 0 to 255. Now we rescale these values to [-1, 1]

# %%
(x_train, y_train), (_, _) = mnist.load_data()

# Rescale -1 to 1
x_train = (x_train.astype(np.float32) - 127.5) / 127.5
x_train = np.expand_dims(x_train, axis=3)

print(x_train.shape)
print(y_train)
x_train = x_train[y_train ==8]
print(x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28, 1)
# [5 0 4 ... 5 6 8]
# (5851, 28, 28, 1)

# %% [markdown]
# Show digits in gray-scale

# %%
samples = np.reshape(x_train[0:16], (-1,28,28,1))
print(np.shape(samples))
plot_images(save2file=False, step=0, images = samples)
# Out:
# (16, 28, 28, 1)
#     ____________________ Step = 0 ____________________

# %%
shp = x_train.shape[1:]
inidim = 100
print(shp)
# Optim
dropout_rate = 0.3
opt  = Adam(lr=2e-4,beta_1=0.5)
dopt = Adam(lr=2e-4,beta_1=0.5)
# Out:
# (28, 28, 1)

# %% [markdown]
# <H2>3. Generator</H2>

# %%
""" Declare a generator. 
    + Its input is a 100-feature vector of random values.
    + its output is a fake image with pixel values in [-1, 1]. """
def generator():
    model = Sequential()
    model.add(Dense(7*7*128, kernel_initializer='glorot_normal',input_shape=(inidim,)))
    model.add(LeakyReLU(0.2))
    model.add(Reshape( [7, 7, 128]))
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(64, (5, 5), padding='same', kernel_initializer='glorot_uniform'))
    model.add(LeakyReLU(0.2))
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(1, (5, 5), padding='same', kernel_initializer='glorot_uniform'))
    model.add(Activation('tanh'))
    return model
print("_____________________ Generator Architecture_____________________")
G = generator()
G.compile(loss='binary_crossentropy', optimizer=opt)
G.summary()
# Out:
# _____________________ Generator Architecture_____________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              633472
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 64)        204864
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 1)         1601
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 1)         0
# =================================================================
# Total params: 839,937
# Trainable params: 839,937
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <H2>4. Discriminator</H2>

# %%
""" Declare discriminator 
    + Its input is image (in a form of a vector 28x28)
    + Its ouput is the probability of image type (real-image or fake image)
    the values in the range of [0, 1] """

def discriminator():
    model = Sequential()
    #model.add(Dense(7*7*128, kernel_initializer='glorot_normal',input_shape=(inidim,)))
    model.add(Conv2D(64, (5, 5), strides=(2, 2), padding= 'same',input_shape=shp))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(dropout_rate))
    model.add(Conv2D(128, (5, 5), strides=(2, 2), padding = 'same'))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(dropout_rate))
    model.add(Flatten())
    model.add(Dense(1,activation='sigmoid'))
    return model
print("___________________ Discriminator Architecture___________________")
D = discriminator()
D.compile(loss='binary_crossentropy', optimizer=dopt)
D.summary()
# Out:
# ___________________ Discriminator Architecture___________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>5. Generative model</h2>
#
# We stack generator and discriminator to form a generative mode (gen_model)

# %% [markdown]
# ### Note: the Train Loop
# - Train the discriminator to become a a classifier of real and fake images
# - Train generator in order to produce fake images from noise
#
# - Therefore, we train the discriminator and the generator in turn in a loop as follows:
#
#     #### Step 1) Set the discriminator trainable
#     #### Step 2) Train the discriminator with the real images and fake images.
#     #### Step 3) Set the discriminator non-trainable
#     #### Step 4) Train the generator as part of the GAN. Feed latent samples into the generator to produce fake images and use the discriminator to classify the images.
#
# The loop should ideally continue until they are both trained well and can not be improved any further.

# %%
"""Thus, we set trainable = False to prevent weight updating in Discriminator"""
def dcgan_model(generator, discriminator):
    #We do not train discriminator this phase 
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    return model

# %%
optimizer = Adam(lr=0.0002, beta_1=0.5, decay=8e-8)

G = generator()
G.compile(loss='binary_crossentropy', optimizer=optimizer)

D = discriminator()
D.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

GAN = dcgan_model(G,D)
GAN.compile(loss='binary_crossentropy', optimizer=optimizer)
GAN.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_2 (Sequential)    (None, 28, 28, 1)         839937
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,052,802
# Trainable params: 839,937
# Non-trainable params: 212,865
# _________________________________________________________________

# %%
epochs     = 1000
batch_size = 32
plt_frq    = 10
samples    = []
losses     = []
    #for e in tqdm(range(nb_epoch)):  
for e in range(epochs):

    # Make generative images
    image_batch = x_train[np.random.choice(x_train.shape[0], size=batch_size),:,:,:]    
    noise_gen = np.random.normal(0,1,size=[batch_size,inidim])
    generated_images = G.predict(noise_gen)

    # Train discriminator on generated images
    X = np.concatenate((image_batch, generated_images))
    y = np.concatenate((np.ones((batch_size, 1)), np.zeros((batch_size, 1))))
    
    D.trainable = True
    d_loss  = D.train_on_batch(X,y)

    
    # train Generator-Discriminator stack on input noise to non-generated output class
    D.trainable = False
    
    noise_tr = np.random.normal(0,1,size=[2*batch_size,inidim])
    y2        = np.ones((2*batch_size, 1))
    g_loss = GAN.train_on_batch(noise_tr, y2 )


    if e%plt_frq==0:        
        noise = np.random.normal(0, 1, (16, 100))
        gen_images = G.predict(noise)
        samples.append(gen_images)
        
        a = [e, d_loss[0], g_loss]
        losses = np.append(losses, a)
        
        print ('epoch: %3.0d, Discriminator :: d_loss: %0.4f], [ Generator :: loss: %0.4f]' % (e, d_loss[0], g_loss))
# Out:
# epoch:   0, Discriminator :: d_loss: 0.7176], [ Generator :: loss: 0.6902]
# epoch:  10, Discriminator :: d_loss: 0.3857], [ Generator :: loss: 1.2448]
# epoch:  20, Discriminator :: d_loss: 0.3157], [ Generator :: loss: 0.9742]
# epoch:  30, Discriminator :: d_loss: 0.4825], [ Generator :: loss: 0.7556]
# epoch:  40, Discriminator :: d_loss: 0.5227], [ Generator :: loss: 0.6442]
# epoch:  50, Discriminator :: d_loss: 0.5656], [ Generator :: loss: 0.6848]
# epoch:  60, Discriminator :: d_loss: 0.5713], [ Generator :: loss: 0.6780]
# epoch:  70, Discriminator :: d_loss: 0.5778], [ Generator :: loss: 0.8018]
# epoch:  80, Discriminator :: d_loss: 0.5925], [ Generator :: loss: 0.8678]
# epoch:  90, Discriminator :: d_loss: 0.6005], [ Generator :: loss: 0.7854]
# epoch: 100, Discriminator :: d_loss: 0.5989], [ Generator :: loss: 0.9911]
# epoch: 110, Discriminator :: d_loss: 0.6381], [ Generator :: loss: 0.6376]
# epoch: 120, Discriminator :: d_loss: 0.5956], [ Generator :: loss: 0.8154]
# epoch: 130, Discriminator :: d_loss: 0.6173], [ Generator :: loss: 0.8688]
# epoch: 140, Discriminator :: d_loss: 0.6803], [ Generator :: loss: 0.7895]
# epoch: 150, Discriminator :: d_loss: 0.6366], [ Generator :: loss: 0.8232]
# epoch: 160, Discriminator :: d_loss: 0.6968], [ Generator :: loss: 0.8348]
# epoch: 170, Discriminator :: d_loss: 0.6372], [ Generator :: loss: 1.2634]
# epoch: 180, Discriminator :: d_loss: 0.7283], [ Generator :: loss: 0.8466]
# epoch: 190, Discriminator :: d_loss: 0.6612], [ Generator :: loss: 0.8730]
# epoch: 200, Discriminator :: d_loss: 0.6264], [ Generator :: loss: 0.7600]
# epoch: 210, Discriminator :: d_loss: 0.6473], [ Generator :: loss: 0.6853]
# epoch: 220, Discriminator :: d_loss: 0.6631], [ Generator :: loss: 0.8005]
# epoch: 230, Discriminator :: d_loss: 0.6234], [ Generator :: loss: 0.8453]
# epoch: 240, Discriminator :: d_loss: 0.7078], [ Generator :: loss: 0.7635]
# epoch: 250, Discriminator :: d_loss: 0.6316], [ Generator :: loss: 0.9822]
# epoch: 260, Discriminator :: d_loss: 0.5513], [ Generator :: loss: 0.9641]
# epoch: 270, Discriminator :: d_loss: 0.6955], [ Generator :: loss: 0.7984]
# epoch: 280, Discriminator :: d_loss: 0.7664], [ Generator :: loss: 0.8232]
# epoch: 290, Discriminator :: d_loss: 0.7355], [ Generator :: loss: 0.7549]
# epoch: 300, Discriminator :: d_loss: 0.6989], [ Generator :: loss: 0.8574]
# epoch: 310, Discriminator :: d_loss: 0.6680], [ Generator :: loss: 0.7487]
# epoch: 320, Discriminator :: d_loss: 0.6716], [ Generator :: loss: 0.8370]
# epoch: 330, Discriminator :: d_loss: 0.6594], [ Generator :: loss: 0.8327]
# epoch: 340, Discriminator :: d_loss: 0.7106], [ Generator :: loss: 0.7637]
# epoch: 350, Discriminator :: d_loss: 0.6854], [ Generator :: loss: 0.8614]
# epoch: 360, Discriminator :: d_loss: 0.7102], [ Generator :: loss: 0.7967]
# epoch: 370, Discriminator :: d_loss: 0.6296], [ Generator :: loss: 0.7984]
# epoch: 380, Discriminator :: d_loss: 0.7098], [ Generator :: loss: 0.8425]
# epoch: 390, Discriminator :: d_loss: 0.6852], [ Generator :: loss: 0.9018]
# epoch: 400, Discriminator :: d_loss: 0.7215], [ Generator :: loss: 0.8442]
# epoch: 410, Discriminator :: d_loss: 0.6737], [ Generator :: loss: 0.8307]
# epoch: 420, Discriminator :: d_loss: 0.6910], [ Generator :: loss: 0.8176]
# epoch: 430, Discriminator :: d_loss: 0.6266], [ Generator :: loss: 0.8007]
# epoch: 440, Discriminator :: d_loss: 0.6785], [ Generator :: loss: 0.7447]
# epoch: 450, Discriminator :: d_loss: 0.5994], [ Generator :: loss: 0.8464]
# epoch: 460, Discriminator :: d_loss: 0.5978], [ Generator :: loss: 0.8912]
# epoch: 470, Discriminator :: d_loss: 0.6809], [ Generator :: loss: 0.8716]
# epoch: 480, Discriminator :: d_loss: 0.5690], [ Generator :: loss: 0.8598]
# epoch: 490, Discriminator :: d_loss: 0.6925], [ Generator :: loss: 0.7527]
# epoch: 500, Discriminator :: d_loss: 0.6297], [ Generator :: loss: 0.8921]
# epoch: 510, Discriminator :: d_loss: 0.6499], [ Generator :: loss: 0.8213]
# epoch: 520, Discriminator :: d_loss: 0.6818], [ Generator :: loss: 0.7674]
# epoch: 530, Discriminator :: d_loss: 0.6820], [ Generator :: loss: 0.7211]
# epoch: 540, Discriminator :: d_loss: 0.7462], [ Generator :: loss: 0.6603]
# epoch: 550, Discriminator :: d_loss: 0.6870], [ Generator :: loss: 0.7752]
# epoch: 560, Discriminator :: d_loss: 0.7404], [ Generator :: loss: 0.8232]
# epoch: 570, Discriminator :: d_loss: 0.6479], [ Generator :: loss: 0.7846]
# epoch: 580, Discriminator :: d_loss: 0.6431], [ Generator :: loss: 0.8176]
# epoch: 590, Discriminator :: d_loss: 0.6323], [ Generator :: loss: 0.7771]
# epoch: 600, Discriminator :: d_loss: 0.6347], [ Generator :: loss: 0.7566]
# epoch: 610, Discriminator :: d_loss: 0.6371], [ Generator :: loss: 0.7648]
# epoch: 620, Discriminator :: d_loss: 0.6340], [ Generator :: loss: 0.7775]
# epoch: 630, Discriminator :: d_loss: 0.6473], [ Generator :: loss: 0.7785]
# epoch: 640, Discriminator :: d_loss: 0.6632], [ Generator :: loss: 0.7427]
# epoch: 650, Discriminator :: d_loss: 0.6888], [ Generator :: loss: 0.7560]
# epoch: 660, Discriminator :: d_loss: 0.6331], [ Generator :: loss: 0.7894]
# epoch: 670, Discriminator :: d_loss: 0.6606], [ Generator :: loss: 0.7497]
# epoch: 680, Discriminator :: d_loss: 0.6329], [ Generator :: loss: 0.8302]
# epoch: 690, Discriminator :: d_loss: 0.6027], [ Generator :: loss: 0.8603]
# epoch: 700, Discriminator :: d_loss: 0.6032], [ Generator :: loss: 0.7564]
# epoch: 710, Discriminator :: d_loss: 0.6349], [ Generator :: loss: 0.8622]
# epoch: 720, Discriminator :: d_loss: 0.6346], [ Generator :: loss: 0.8232]
# epoch: 730, Discriminator :: d_loss: 0.6441], [ Generator :: loss: 0.8423]
# epoch: 740, Discriminator :: d_loss: 0.6509], [ Generator :: loss: 0.7164]
# epoch: 750, Discriminator :: d_loss: 0.6240], [ Generator :: loss: 0.8659]
# epoch: 760, Discriminator :: d_loss: 0.6225], [ Generator :: loss: 0.7671]
# epoch: 770, Discriminator :: d_loss: 0.6615], [ Generator :: loss: 0.7099]
# epoch: 780, Discriminator :: d_loss: 0.6732], [ Generator :: loss: 0.7529]
# epoch: 790, Discriminator :: d_loss: 0.7296], [ Generator :: loss: 0.7815]
# epoch: 800, Discriminator :: d_loss: 0.6514], [ Generator :: loss: 0.7204]
# epoch: 810, Discriminator :: d_loss: 0.6515], [ Generator :: loss: 0.7807]
# epoch: 820, Discriminator :: d_loss: 0.6780], [ Generator :: loss: 0.7435]
# epoch: 830, Discriminator :: d_loss: 0.6276], [ Generator :: loss: 0.7595]
# epoch: 840, Discriminator :: d_loss: 0.6620], [ Generator :: loss: 0.8025]
# epoch: 850, Discriminator :: d_loss: 0.6495], [ Generator :: loss: 0.8096]
# epoch: 860, Discriminator :: d_loss: 0.6130], [ Generator :: loss: 0.8303]
# epoch: 870, Discriminator :: d_loss: 0.6300], [ Generator :: loss: 0.7592]
# epoch: 880, Discriminator :: d_loss: 0.6972], [ Generator :: loss: 0.8149]
# epoch: 890, Discriminator :: d_loss: 0.6937], [ Generator :: loss: 0.7809]
# epoch: 900, Discriminator :: d_loss: 0.6350], [ Generator :: loss: 0.7669]
# epoch: 910, Discriminator :: d_loss: 0.6757], [ Generator :: loss: 0.8484]
# epoch: 920, Discriminator :: d_loss: 0.6402], [ Generator :: loss: 0.8204]
# epoch: 930, Discriminator :: d_loss: 0.6585], [ Generator :: loss: 0.8187]
# epoch: 940, Discriminator :: d_loss: 0.6188], [ Generator :: loss: 0.7597]
# epoch: 950, Discriminator :: d_loss: 0.6897], [ Generator :: loss: 0.7930]
# epoch: 960, Discriminator :: d_loss: 0.7282], [ Generator :: loss: 0.8112]
# epoch: 970, Discriminator :: d_loss: 0.7314], [ Generator :: loss: 0.6950]
# epoch: 980, Discriminator :: d_loss: 0.6994], [ Generator :: loss: 0.7481]
# epoch: 990, Discriminator :: d_loss: 0.6427], [ Generator :: loss: 0.8056]

# %%
losses = np.reshape(losses, (-1,3))
Plot_losses(losses, -0.1, 2)
print("DCGAN is difficult to converge because the training processes of Generator and Discriminator are conflict each others. \n")
# Out:
# DCGAN is difficult to converge because the training processes of Generator and Discriminator are conflict each others.

# %%
i = 0
for images in samples:
    step = i*plt_frq
    plot_images(save2file=False, step=step, images = images)
    print("\n")
    i = i + 1
# Out:
#     ____________________ Step = 0 ____________________
#     ____________________ Step = 10 ____________________
#     ____________________ Step = 20 ____________________
#     ____________________ Step = 30 ____________________
#     ____________________ Step = 40 ____________________
#     ____________________ Step = 50 ____________________
#     ____________________ Step = 60 ____________________
#     ____________________ Step = 70 ____________________
#     ____________________ Step = 80 ____________________
#     ____________________ Step = 90 ____________________
#     ____________________ Step = 100 ____________________
#     ____________________ Step = 110 ____________________
#     ____________________ Step = 120 ____________________
#     ____________________ Step = 130 ____________________
#     ____________________ Step = 140 ____________________
#     ____________________ Step = 150 ____________________
#     ____________________ Step = 160 ____________________
#     ____________________ Step = 170 ____________________
#     ____________________ Step = 180 ____________________
#     ____________________ Step = 190 ____________________
#     ____________________ Step = 200 ____________________
#     ____________________ Step = 210 ____________________
#     ____________________ Step = 220 ____________________
#     ____________________ Step = 230 ____________________
#     ____________________ Step = 240 ____________________
#     ____________________ Step = 250 ____________________
#     ____________________ Step = 260 ____________________
#     ____________________ Step = 270 ____________________
#     ____________________ Step = 280 ____________________
#     ____________________ Step = 290 ____________________
#     ____________________ Step = 300 ____________________
#     ____________________ Step = 310 ____________________
#     ____________________ Step = 320 ____________________
#     ____________________ Step = 330 ____________________
#     ____________________ Step = 340 ____________________
#     ____________________ Step = 350 ____________________
#     ____________________ Step = 360 ____________________
#     ____________________ Step = 370 ____________________
#     ____________________ Step = 380 ____________________
#     ____________________ Step = 390 ____________________
#     ____________________ Step = 400 ____________________
#     ____________________ Step = 410 ____________________
#     ____________________ Step = 420 ____________________
#     ____________________ Step = 430 ____________________
#     ____________________ Step = 440 ____________________
#     ____________________ Step = 450 ____________________
#     ____________________ Step = 460 ____________________
#     ____________________ Step = 470 ____________________
#     ____________________ Step = 480 ____________________
#     ____________________ Step = 490 ____________________
#     ____________________ Step = 500 ____________________
#     ____________________ Step = 510 ____________________
#     ____________________ Step = 520 ____________________
#     ____________________ Step = 530 ____________________
#     ____________________ Step = 540 ____________________
#     ____________________ Step = 550 ____________________
#     ____________________ Step = 560 ____________________
#     ____________________ Step = 570 ____________________
#     ____________________ Step = 580 ____________________
#     ____________________ Step = 590 ____________________
#     ____________________ Step = 600 ____________________
#     ____________________ Step = 610 ____________________
#     ____________________ Step = 620 ____________________
#     ____________________ Step = 630 ____________________
#     ____________________ Step = 640 ____________________
#     ____________________ Step = 650 ____________________
#     ____________________ Step = 660 ____________________
#     ____________________ Step = 670 ____________________
#     ____________________ Step = 680 ____________________
#     ____________________ Step = 690 ____________________
#     ____________________ Step = 700 ____________________
#     ____________________ Step = 710 ____________________
#     ____________________ Step = 720 ____________________
#     ____________________ Step = 730 ____________________
#     ____________________ Step = 740 ____________________
#     ____________________ Step = 750 ____________________
#     ____________________ Step = 760 ____________________
#     ____________________ Step = 770 ____________________
#     ____________________ Step = 780 ____________________
#     ____________________ Step = 790 ____________________
#     ____________________ Step = 800 ____________________
#     ____________________ Step = 810 ____________________
#     ____________________ Step = 820 ____________________
#     ____________________ Step = 830 ____________________
#     ____________________ Step = 840 ____________________
#     ____________________ Step = 850 ____________________
#     ____________________ Step = 860 ____________________
#     ____________________ Step = 870 ____________________
#     ____________________ Step = 880 ____________________
#     ____________________ Step = 890 ____________________
#     ____________________ Step = 900 ____________________
#     ____________________ Step = 910 ____________________
#     ____________________ Step = 920 ____________________
#     ____________________ Step = 930 ____________________
#     ____________________ Step = 940 ____________________
#     ____________________ Step = 950 ____________________
#     ____________________ Step = 960 ____________________
#     ____________________ Step = 970 ____________________
#     ____________________ Step = 980 ____________________
#     ____________________ Step = 990 ____________________
